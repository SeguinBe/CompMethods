# %%
# !pip install xmltodict

# %%
import requests
import xmltodict

# %% [markdown]
# ## Accessing a resource in python

# %%
import requests

# Perform a HTTP GET request on the desired URL
response = requests.get('https://www.google.com')

# %%
# Object response, with status code 200, which means the request succeded
response
# Out:
# <Response [200]>

# %% [markdown]
# ### Checking Response

# %%
# The code of the response can be accessed
response.status_code
# Out:
# 200

# %%
# We will always get a response object, even if the request was not successful (assuming the server exists)
# Here we generate an error if the request failed. If the request was a success, nothing is raised
response.raise_for_status()

# %%
# And here we check directly if the status is one of the good ones
response.ok
# Out:
# True

# %%
# Failure case, resource not found
response = requests.get('https://www.google.com/totally-not-existing-path-that-google-will-not-answer')
print(response.ok)
print(response.status_code)
print(response.reason)
# Out:
# False
# 404
# Not Found

# %%
response.raise_for_status()
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-8-98371c55c61f> in <module>
# ----> 1 response.raise_for_status()
#
# ~/miniconda3/envs/archi/lib/python3.6/site-packages/requests/models.py in raise_for_status(self)
#     938
#     939         if http_error_msg:
# --> 940             raise HTTPError(http_error_msg, response=self)
#     941
#     942     def close(self):
#
# HTTPError: 404 Client Error: Not Found for url: https://www.google.com/totally-not-existing-path-that-google-will-not-answer

# %% [markdown]
# ### Accessing content

# %%
response = requests.get('https://www.google.com')
# The content of the answer can directly be accessed with .content
# Here we display the source code of the google webpage
response.content
# Out:
# b'<!doctype html><html itemscope="" itemtype="http://schema.org/WebPage" lang="fr"><head><meta content="text/html; charset=UTF-8" http-equiv="Content-Type"><meta content="/logos/doodles/2020/thank-you-public-health-workers-and-to-researchers-in-the-scientific-community-6753651837108753-law.gif" itemprop="image"><meta content="Merci \xe0 tous les personnels de sant\xe9 et \xe0 tous les chercheurs" property="twitter:title"><meta content="Merci \xe0 tous les personnels de sant\xe9 et \xe0 tous les chercheurs #GoogleDoodle" property="twitter:description"><meta content="Merci \xe0 tous les personnels de sant\xe9 et \xe0 tous les chercheurs #GoogleDoodle" property="og:description"><meta content="summary_large_image" property="twitter:card"><meta content="@GoogleDoodles" property="twitter:site"><meta content="https://www.google.com/logos/doodles/2020/thank-you-public-health-workers-and-to-researchers-in-the-scientific-community-6753651837108753.3-2xa.gif" property="twitter:image"><meta content="https://www.google.com/logos/doodles/2020/thank-you-public-health-workers-and-to-researchers-in-the-scientific-community-6753651837108753.3-2xa.gif" property="og:image"><meta content="1380" property="og:image:width"><meta content="448" property="og:image:height"><meta content="https://www.google.com/logos/doodles/2020/thank-you-public-health-workers-and-to-researchers-in-the-scientific-community-6753651837108753.3-2xa.gif" property="og:url"><meta content="video.other" property="og:type"><title>Google</title><script nonce="9pBeUaGk05490L1VjTo9ew==">(function(){window.google={kEI:\'svmKXuCiA6-XlwSm9ZLAAg\',kEXPI:\'0,202123,3,1151620,5663,730,224,756,2901,1447,207,3204,10,289,762,175,364,926,192,317,4,60,238,579,383,139,107,5,767,243,9,18,42,275,530,243,40,103,5,268,176,51,150,1126200,1197755,136,133,125,329118,1294,12383,4855,32691,15248,867,28684,364,8824,8384,4858,1362,9290,3030,4738,3118,7915,1808,4020,978,7931,5297,2054,920,2090,2975,6430,7432,3874,2883,21,318,4519,1396,1379,520,399,262,2015,8,2796,1593,1279,2212,202,329,148,1103,840,517,1466,8,48,157,663,3438,312,1137,2,2063,606,1839,184,1777,520,1947,747,1482,93,328,1284,16,2927,23,2224,473,1339,748,1039,3227,773,2072,7,7633,6513,2663,641,599,1851,2458,1226,1462,3935,1274,108,1456,1951,908,2,1473,6,316,241,1519,2397,808,3550,1061,225,996,830,840,480,606,1349,3,346,200,30,157,813,183,561,121,8,370,1011,623,1906,440,266,149,189,3313,1460,1030,26,201,248,913,589,273,121,2285,192,1391,83,1018,643,1,1,2,122,995,411,17,126,76,102,112,205,4,2,297,70,4,279,8,986,16,152,182,483,141,15,55,186,22,271,373,225,276,110,285,2,8,41,64,128,309,249,379,221,2,195,272,649,610,498,338,175,39,32,134,125,360,534,117,88,197,158,130,127,4,7,648,244,5830612,3275,1802618,6996022,549,333,444,1,2,80,1,900,896,1,8,1,2,2551,1,748,141,795,10,553,1,4265,1,1,1,1,137,1,1193,722,450,229,3,5,7,4,1,15,2,2,1,1,1,2,11,4,1,1,1,5,3,2,3,7,2,1,1,1,1,4,1,10,1,3,23962895,24\',kBL:\'-KLY\'};google.sn=\'webhp\';google.kHL=\'fr\';})();(function(){google.lc=[];google.li=0;google.getEI=function(a){for(var c;a&&(!a.getAttribute||!(c=a.getAttribute("eid")));)a=a.parentNode;return c||google.kEI};google.getLEI=function(a){for(var c=null;a&&(!a.getAttribute||!(c=a.getAttribute("leid")));)a=a.parentNode;return c};google.ml=function(){return null};google.time=function(){return Date.now()};google.log=function(a,c,b,d,g){if(b=google.logUrl(a,c,b,d,g)){a=new Image;var e=google.lc,f=google.li;e[f]=a;a.onerror=a.onload=a.onabort=function(){delete e[f]};google.vel&&google.vel.lu&&google.vel.lu(b);a.src=b;google.li=f+1}};google.logUrl=function(a,c,b,d,g){var e="",f=google.ls||"";b||-1!=c.search("&ei=")||(e="&ei="+google.getEI(d),-1==c.search("&lei=")&&(d=google.getLEI(d))&&(e+="&lei="+d));d="";!b&&google.cshid&&-1==c.search("&cshid=")&&"slh"!=a&&(d="&cshid="+google.cshid);b=b||"/"+(g||"gen_204")+"?atyp=i&ct="+a+"&cad="+c+e+f+"&zx="+google.time()+d;/^http:/i.test(b)&&"https:"==window.location.protocol&&(google.ml(Error("a"),!1,{src:b,glmm:1}),b="");retur ...

# %%
# Access the full text representation of https://www.e-rara.ch/oec/vitruviana/content/titleinfo/6116002
response = requests.get('https://www.e-rara.ch/oec/download/fulltext/plain/6116002')
response.status_code
# Out:
# 200

# %%
# By default response are raw bytes, binary format
response.content[1000:2000]  # Showing just 1000 characters
# Out:
# b'se rattache \xc3\xa0 son souvenir. Deux \xc3\xa9crivains pourtant semblent avoir enregistr\xc3\xa9 son nom dans leurs \xc3\xa9crits, comme pour indiquer qu\xe2\x80\x99il v\xc3\xa9cut : Pline, qui le cite au nombre des auteurs dont il s\xe2\x80\x99est servi; Frontin, qui le nomme comme ayant \xc3\xa9t\xc3\xa9 r\xc3\xa9put\xc3\xa9 l\xe2\x80\x99inventeur du module quinaire dans les aqueducs. On ne peut donc savoir sur la vie de Vitruve que ce qu\xe2\x80\x99il en a dit lui-m\xc3\xaame : or, il nous apprend qu\xe2\x80\x99il occupa un rang assez important dans les arm\xc3\xa9es de J. C\xc3\xa9sar, aupr\xc3\xa8s duquel il jouissait d\xe2\x80\x99une certaine consid\xc3\xa9ration ; que, de concert avec M. Aurelius, P. Numidius et L. Cornelius, il fut employ\xc3\xa9 \xc3\xa0 la construction des machines de guerre ; qu\xe2\x80\x99il \xc3\xa9leva la basilique de Fano; que, gr\xc3\xa2ce \xc3\xa0 la recommandation de la s\xc5\x93ur d\xe2\x80\x99Auguste, il dut \xc3\xa0 cet empereur, auquel il d\xc3\xa9die son ouvrage, des gratifications qui mettaient ses vieux jours \xc3\xa0 l\xe2\x80\x99abri du besoin *. Sa taille \xc3\xa9tait peu avantageuse ; il avait une constitution maladive : mais il ne d\xc3\xa9sesp\xc3\xa9rait pas de rachet'

# %%
# Getting a nicely encoded version
response.text[1000:2000]
# Out:
# 'oir enregistré son nom dans leurs écrits, comme pour indiquer qu’il vécut : Pline, qui le cite au nombre des auteurs dont il s’est servi; Frontin, qui le nomme comme ayant été réputé l’inventeur du module quinaire dans les aqueducs. On ne peut donc savoir sur la vie de Vitruve que ce qu’il en a dit lui-même : or, il nous apprend qu’il occupa un rang assez important dans les armées de J. César, auprès duquel il jouissait d’une certaine considération ; que, de concert avec M. Aurelius, P. Numidius et L. Cornelius, il fut employé à la construction des machines de guerre ; qu’il éleva la basilique de Fano; que, grâce à la recommandation de la sœur d’Auguste, il dut à cet empereur, auquel il dédie son ouvrage, des gratifications qui mettaient ses vieux jours à l’abri du besoin *. Sa taille était peu avantageuse ; il avait une constitution maladive : mais il ne désespérait pas de racheter par ses connaissances ce qui lui manquait du côté des qualités physiques Il n’eut point de maîtres, ou p'

# %%
# Saving it to a file
with open('e-rara_text.txt' , 'w', encoding='utf-8') as f:
    f.write(response.text)

# %% [markdown]
# ### Downloading a file directly

# %%
GTA_LOGO_URL = 'https://upload.wikimedia.org/wikipedia/commons/thumb/b/b9/Gta_logo.jpg/240px-Gta_logo.jpg'

# %%
response = requests.get(GTA_LOGO_URL)
response.raise_for_status()
# Writing in binary mode 'wb'
with open('gta_logo.jpg', 'wb') as f:
    f.write(response.content)

# %% [markdown]
# NOTE FOR COMPLETENESS: in this situation the file is fully downloaded in memory and then written to disk. For large files, this might not be appropriate and streaming should be used (see https://stackoverflow.com/a/34503421/2911687).

# %% [markdown]
# ### Getting structured data

# %%
# Getting a IIIF Presentation manifest
response = requests.get('https://www.e-rara.ch/i3f/v20/6116002/manifest')

# %%
# We know IIIF manifest are JSON encoded, so we can parse the raw response to convert it to a nice python dict
import json
data_as_python_dict = json.loads(response.content)
# Accessing the metadata as stipulated by the Presentation API
data_as_python_dict['metadata']
# Out:
# [{'value': "L' architecture de Vitruve / trad. nouvelle par Ch.-L. Maufras",
#   'label': 'Titel'},
#  {'value': 'Vitruvius [ca. v1. Jh]; Maufras, Ch. L.',
#   'label': 'Autor, Beteiligte'},
#  {'value': 'Paris : Panckoucke, 1847', 'label': 'Impressum'},
#  {'value': '2 tomes :  : Ill.', 'label': 'Umfang'},
#  {'value': 'Französisch ; Latein', 'label': 'Sprache'},
#  {'value': 'Stiftung Bibliothek Werner Oechslin, Einsiedeln, A04c ; app. 846',
#   'label': 'Besitzende Institution'},
#  {'value': 'Bibliothèque latine-française. Seconde série', 'label': 'Serie'},
#  {'value': 'https://doi.org/10.3931/e-rara-19457', 'label': 'DOI'}]

# %%
# Shortcut version, equivalent to manual json parsing above
data_as_python_dict = response.json()
# Accessing the info about the first page of the first sequence
data_as_python_dict['sequences'][0]['canvases'][0]
# Out:
# {'height': 3714,
#  'width': 2460,
#  'images': [{'resource': {'service': {'profile': 'http://iiif.io/api/image/2/level2.json',
#      '@context': 'http://iiif.io/api/image/2/context.json',
#      '@id': 'https://www.e-rara.ch/oec/i3f/v20/6116005'},
#     'format': 'image/jpeg',
#     'height': 1509,
#     'width': 1000,
#     '@id': 'https://www.e-rara.ch/oec/download/webcache/1000/6116005',
#     '@type': 'dctypes:Image'},
#    'on': 'https://www.e-rara.ch/oec/i3f/v20/6116002/canvas/6116005',
#    'motivation': 'sc:painting',
#    '@id': 'https://www.e-rara.ch/oec/i3f/v20/6116002/annotation/6116005',
#    '@type': 'oa:Annotation'}],
#  'label': '[1]',
#  '@id': 'https://www.e-rara.ch/oec/i3f/v20/6116002/canvas/6116005',
#  '@type': 'sc:Canvas'}

# %% [markdown]
# ### Request with parameters
#
# Accessing OAI endpoint of e-rara, getting the information about a specific record, notice the structure of the url
#
# https://www.e-rara.ch/oec/oai?verb=GetRecord&metadataPrefix=oai_dc&identifier=6116002

# %%
response = requests.get('https://www.e-rara.ch/oec/oai?verb=GetRecord&metadataPrefix=oai_dc&identifier=6116002')
response.content
# Out:
# b'<OAI-PMH xmlns="http://www.openarchives.org/OAI/2.0/" xmlns:mets="http://www.loc.gov/METS/" xmlns:mods="http://www.loc.gov/mods/v3" xmlns:oai_dc="http://www.openarchives.org/OAI/2.0/oai_dc/" xmlns:epicur="urn:nbn:de:1111-2004033116" xmlns:vl="http://visuallibrary.net/vl" xmlns:dc="http://purl.org/dc/elements/1.1/" xmlns:oai="http://www.openarchives.org/OAI/2.0/" xmlns:marcxml="http://www.loc.gov/MARC21/slim" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:schemaLocation="http://www.openarchives.org/OAI/2.0/ http://www.openarchives.org/OAI/2.0/OAI-PMH.xsd"><responseDate>2020-04-06T09:43:33Z</responseDate><request verb="GetRecord" metadataPrefix="oai_dc" identifier="6116002">https://www.e-rara.ch/oec/oai/</request><GetRecord><record><header><identifier>oai:www.e-rara.ch/oec:6116002</identifier><datestamp>2013-11-13T12:26:07Z</datestamp><setSpec>oec</setSpec><setSpec>book</setSpec></header><metadata><oai_dc:dc xsi:schemaLocation="http://purl.org/dc/elements/1.1/ http://www.openarchives.org/OAI/2.0/oai_dc.xsd"><dc:title>L\' architecture de Vitruve</dc:title><dc:creator>Vitruvius</dc:creator><dc:description>trad. nouvelle par Ch.-L. Maufras</dc:description><dc:description>Lat.-franz. Paralleltext</dc:description><dc:description>Originaltitel: De architectura libri decem Vitruvius Pollio</dc:description><dc:publisher>Panckoucke</dc:publisher><dc:contributor>Maufras, Ch. L.</dc:contributor><dc:date>1847</dc:date><dc:type>Text</dc:type><dc:type>Book</dc:type><dc:format>2 tomes :</dc:format><dc:format>Ill.</dc:format><dc:identifier>doi:10.3931/e-rara-19457</dc:identifier><dc:identifier>https://www.e-rara.ch/oec/doi/10.3931/e-rara-19457</dc:identifier><dc:identifier>system:004370068</dc:identifier><dc:relation>vignette : https://www.e-rara.ch/oec/titlepage/doi/10.3931/e-rara-19457/128</dc:relation><dc:language>fre</dc:language><dc:rights>pdm</dc:rights></oai_dc:dc></metadata></record></GetRecord></OAI-PMH>'

# %%
# Format of OAI is xml so we can parse it as well
parsed_response = xmltodict.parse(response.content)
parsed_response
# Out:
# OrderedDict([('OAI-PMH',
#               OrderedDict([('@xmlns', 'http://www.openarchives.org/OAI/2.0/'),
#                            ('@xmlns:mets', 'http://www.loc.gov/METS/'),
#                            ('@xmlns:mods', 'http://www.loc.gov/mods/v3'),
#                            ('@xmlns:oai_dc',
#                             'http://www.openarchives.org/OAI/2.0/oai_dc/'),
#                            ('@xmlns:epicur', 'urn:nbn:de:1111-2004033116'),
#                            ('@xmlns:vl', 'http://visuallibrary.net/vl'),
#                            ('@xmlns:dc', 'http://purl.org/dc/elements/1.1/'),
#                            ('@xmlns:oai',
#                             'http://www.openarchives.org/OAI/2.0/'),
#                            ('@xmlns:marcxml',
#                             'http://www.loc.gov/MARC21/slim'),
#                            ('@xmlns:xsi',
#                             'http://www.w3.org/2001/XMLSchema-instance'),
#                            ('@xsi:schemaLocation',
#                             'http://www.openarchives.org/OAI/2.0/ http://www.openarchives.org/OAI/2.0/OAI-PMH.xsd'),
#                            ('responseDate', '2020-04-06T09:43:33Z'),
#                            ('request',
#                             OrderedDict([('@verb', 'GetRecord'),
#                                          ('@metadataPrefix', 'oai_dc'),
#                                          ('@identifier', '6116002'),
#                                          ('#text',
#                                           'https://www.e-rara.ch/oec/oai/')])),
#                            ('GetRecord',
#                             OrderedDict([('record',
#                                           OrderedDict([('header',
#                                                         OrderedDict([('identifier',
#                                                                       'oai:www.e-rara.ch/oec:6116002'),
#                                                                      ('datestamp',
#                                                                       '2013-11-13T12:26:07Z'),
#                                                                      ('setSpec',
#                                                                       ['oec',
#                                                                        'book'])])),
#                                                        ('metadata',
#                                                         OrderedDict([('oai_dc:dc',
#                                                                       OrderedDict([('@xsi:schemaLocation',
#                                                                                     'http://purl.org/dc/elements/1.1/ http://www.openarchives.org/OAI/2.0/oai_dc.xsd'),
#                                                                                    ('dc:title',
#                                                                                     "L' architecture de Vitruve"),
#                                                                                    ('dc:creator',
#                                                                                     'Vitruvius'),
#                                                                                    ('dc:description',
#                                                                                     ['trad. nouvelle par Ch.-L. Maufras',
#                                                                                      'Lat.-franz. Paralleltext',
#                                                                                      'Originaltitel: De architectura libri decem Vitruvius Pollio']),
#                                                                                    ('dc:publisher',
#                                                                                     'Panckoucke'),
#                                                                                    ('dc:contributor',
#                                                                                     'Maufras, Ch. L.'),
#                                                                                    ('dc:date',
#                                                                                     '1847'),
#                                                                                    ('dc:type',
#                                                                                     ['Text',
#                                                                                      'Book']),
#                                                                                    ('dc:format',
#                                                                                     ['2 tomes :',
#                                                                                      'Ill.']),
#                                                                                    ('dc:identifier',
#                                                                                     ['doi:10.3931/e-rara-19457',
#                                                                                      'https://www.e-rara.ch/oec/doi/10.3931/e-rara-19457',
#                                                                                      'system:004370068']),
#                                                                                    ('dc:relation',
#                                                                                     'vignette : https://www.e-rara.ch/oec/titlepage/doi/10.3931/e-rara-19457/128'),
#                                                                                    ('dc:language',
#                                                                                     'fre'),
#                                                                                    ('dc:rights',
#                                                                                     'pdm')]))]))]))]))]))])

# %%
parsed_response['OAI-PMH']['GetRecord']['record']['metadata']['oai_dc:dc']
# Out:
# OrderedDict([('@xsi:schemaLocation',
#               'http://purl.org/dc/elements/1.1/ http://www.openarchives.org/OAI/2.0/oai_dc.xsd'),
#              ('dc:title', "L' architecture de Vitruve"),
#              ('dc:creator', 'Vitruvius'),
#              ('dc:description',
#               ['trad. nouvelle par Ch.-L. Maufras',
#                'Lat.-franz. Paralleltext',
#                'Originaltitel: De architectura libri decem Vitruvius Pollio']),
#              ('dc:publisher', 'Panckoucke'),
#              ('dc:contributor', 'Maufras, Ch. L.'),
#              ('dc:date', '1847'),
#              ('dc:type', ['Text', 'Book']),
#              ('dc:format', ['2 tomes :', 'Ill.']),
#              ('dc:identifier',
#               ['doi:10.3931/e-rara-19457',
#                'https://www.e-rara.ch/oec/doi/10.3931/e-rara-19457',
#                'system:004370068']),
#              ('dc:relation',
#               'vignette : https://www.e-rara.ch/oec/titlepage/doi/10.3931/e-rara-19457/128'),
#              ('dc:language', 'fre'),
#              ('dc:rights', 'pdm')])

# %% [markdown]
# NOTE: In the case of e-rara, the METS format is much more complete and has links for PDF, OCR and images downloads.
#
# https://www.e-rara.ch/oec/oai?verb=GetRecord&metadataPrefix=mets&identifier=6116002

# %% [markdown]
# # Playing with the BNF APIs
#
# Gallica (the BNF online repository) has multiple APIs for accessing its data (all documented in French unfortunately, google translate might be your friend if you want to have a deeper look):
#
# - A search API in their collection, giving us directly records in OAI format (http://api.bnf.fr/api-gallica-de-recherche):
#
# https://gallica.bnf.fr/SRU?version=1.2&operation=searchRetrieve&suggest=0&query=%28dc.creator+all+%22Vitruve%22%29
#
# - A pagination API to know if the text was OCRized, if the table of content was detected, etc...:
#
# https://gallica.bnf.fr/services/Pagination?ark=bpt6k5839083t

# %% [markdown]
# ## Search with API
#
# Queries are done in CQL (https://www.loc.gov/standards/sru/cql/ from the Library of Congress). Some examples are below

# %%
def request_and_parse(xml_url):
    """Get an xml url and parse it into a python dict"""
    print(f"Fetching {xml_url}")
    result = requests.get(xml_url)
    result.raise_for_status()
    result_parsed = xmltodict.parse(result.content)
    return result_parsed

SRU_BASEURL = 'https://gallica.bnf.fr/SRU?version=1.2&operation=searchRetrieve&suggest=0&query='

# %%
# Example queries
# Query all documents related to "Architecture" (code 72 in Dewey classification)
# Note: that only brings 585 documents, which is much lower than all architecture documents in Gallica...
query = '(sdewey all "72")'
# Queyr all documents where Vitruve is an author
query = '(dc.creator all "Vitruve")'

# %%
from urllib.parse import quote_plus
# Do a simple search
# Since query has spaces and maybe strange characters in it, we make it url-safe with the function quote_plus
# That will for instance convert spaces to '+'
request_and_parse(SRU_BASEURL + quote_plus(query))
# Out:
# Fetching https://gallica.bnf.fr/SRU?version=1.2&operation=searchRetrieve&suggest=0&query=%28dc.creator+all+%22Vitruve%22%29
# OrderedDict([('srw:searchRetrieveResponse',
#               OrderedDict([('@xmlns:ns7',
#                             'http://gallica.bnf.fr/namespaces/gallica/'),
#                            ('@xmlns:oai_dc',
#                             'http://www.openarchives.org/OAI/2.0/oai_dc/'),
#                            ('@xmlns:onix_dc',
#                             'http://bibnum.bnf.fr/NS/onix_dc/'),
#                            ('@xmlns:srw', 'http://www.loc.gov/zing/srw/'),
#                            ('@xmlns:onix',
#                             'http://www.editeur.org/onix/2.1/reference/'),
#                            ('@xmlns:dc', 'http://purl.org/dc/elements/1.1/'),
#                            ('srw:version', '1.2'),
#                            ('srw:echoedSearchRetrieveRequest',
#                             OrderedDict([('srw:query',
#                                           '(dc.creator all "Vitruve")'),
#                                          ('srw:version', '1.2')])),
#                            ('srw:numberOfRecords', '61'),
#                            ('srw:extraResponseData',
#                             '<numberOfRecordsDecollapser>68</numberOfRecordsDecollapser>'),
#                            ('srw:records',
#                             OrderedDict([('srw:record',
#                                           [OrderedDict([('srw:recordSchema',
#                                                          'http://www.openarchives.org/OAI/2.0/OAIdc.xsd'),
#                                                         ('srw:recordPacking',
#                                                          'xml'),
#                                                         ('srw:recordData',
#                                                          OrderedDict([('oai_dc:dc',
#                                                                        OrderedDict([('dc:creator',
#                                                                                      ['Goujon, Jean (1510?-1567?). Dessinateur',
#                                                                                       'Vitruve (0090?-0020? av. J.-C.). Auteur du texte']),
#                                                                                     ('dc:date',
#                                                                                      '1547'),
#                                                                                     ('dc:description',
#                                                                                      ['Thème : Architecture',
#                                                                                       'Dessins et plans -- +* 1500......- 1599......+:16e siècle:']),
#                                                                                     ('dc:format',
#                                                                                      ['139 est. : gravures en taille-douce : n. et b. ; 23 X 31 cm et moins',
#                                                                                       'image/jpeg']),
#                                                                                     ('dc:identifier',
#                                                                                      'https://gallica.bnf.fr/ark:/12148/btv1b21000411'),
#                                                                                     ('dc:language',
#                                                                                      ['fre',
#                                                                                       'français']),
#                                                                                     ('dc:publisher',
#                                                                                      '(Paris)'),
#                                                                                     ('dc:relation',
#                                                                                      'Notice du catalogue : http://catalogue.bnf.fr/ark:/12148/cb384952103'),
#                                                                                     ('dc:rights',
#                                                                                      ['domaine public',
#                                                                                       'public domain']),
#                                                                                     ('dc:source',
#                                                                                      'Bibliothèque nationale de France'),
#                                                                                     ('dc:subject',
#                                                                                      ['Architecture',
#                                                                                       "Vues d'architecture"]),
#                                                                                     ('dc:title',
#                                                                                      '[Illustrations de Architecture ou Art de bien bastir, mis de latin en fraçoys par Ian Martin.] / Jean Goujon [ill. et grav.] ; Marc Pollion Vitruve [aut. de texte] ; Ian Martin [trad.]'),
#                                                                                     ('dc:type',
#                                                                                      ['image fixe',
#                                                                                       'image',
#                                                                                       'still image'])]))])),
#                                                         ('srw:recordIdentifier',
#                                                          'ark'),
#                                                         ('srw:recordPosition',
#                                                          '0'),
#                                                         ('srw:extraRecordData',
#                                                          OrderedDict([('epubFile',
#                                                                        None),
#                                                                       ('infoSupModifiable',
#                                                                        None),
#                                                                       ('link',
#                                                                        'https://gallica.bnf.fr/ark:/12148/btv1b21000411'),
#                                                                       ('nqamoyen',
#                                                                        '0.0'),
#                                                                       ('thumbnail',
#                                                                        'https://gallica.bnf.fr/ark:/12148/btv1b21000411.thumbnail'),
#                                                                       ('typedoc',
#                                                                        'images'),
#                                                                       ('uri',
#                                                                        'btv1b21000411')]))]),
#                                            OrderedDict([('srw:recordSchema',
#                                                          'http://www.openarchives.org/OAI/2.0/OAIdc.xsd'),
#                                                         ('srw:recordPacking',
#                                                          'xml'),
#                                                         ('srw:recordData',
#                                                          OrderedDict([('oai_dc:dc',
#                                                                        OrderedDict([('dc:creator',
#                                                                                      ['Renard, François-Augustin. Auteur du texte',
#                                                                                       'Vitruve (0090?-0020? av. J.-C.). Auteur du texte']),
#                                                                                     ('dc:date',
#                                                                                      '1854'),
#                                                                                     ('dc:description',
#                                                                                      ["Comprend : Principes de l'architecture suivant Vitruve",
#                                                                                       'Contient une table des matières',
#                                                                                       'Avec mode texte']),
#                                                                                     ('dc:format',
#                                                                                      ['In-fol., 43 p. de texte, 43 pl., texte intercalaire, fig., table',
#                                                                                       'Nombre total de vues : 232']),
#                                                                                     ('dc:identifier',
#                                                                                      'https://gallica.bnf.fr/ark:/12148/bpt6k5839083t'),
#                                                                                     ('dc:language',
#                                                                                      ['fre',
#                                                                                       'français']),
#                                                                                     ('dc:publisher',
#                                                                                      'Carilian Goeury et V. Dalmont (Paris)'),
#                                                                                     ('dc:relation',
#                                                                                      'Notice du catalogue : http://catalogue.bnf.fr/ark:/12148/cb311959069'),
#                                                                                     ('dc:rights',
#                                                                                      ['domaine public',
#                                                                                       'public domain']),
#                                                                                     ('dc:source',
#                                                                                      'Bibliothèque nationale de France, département Littérature et art, V-5656'),
#                                                                                     ('dc:title',
#                                                                                      "Architecture décimale. Parallèle des ordres d'architecture et de leurs principales applications... précédé des principes de l'architecture suivant Vitruve, par F. A. Renard,..."),
#                                                                                     ('dc:type',
#                                                                                      ['text',
#                                                                                       'monographie imprimée',
#                                                                                       'monographie imprimée'])]))])),
#                                                         ('srw:recordIdentifier',
#                                                          'ark'),
#                                                         ('srw:recordPosition',
#                                                          '1'),
#                                                         ('srw:extraRecordData',
#                                                          OrderedDict([('epubFile',
#                                                                        None),
#                                                                       ('infoSupModifiable',
#                                                                        None),
#                                                                       ('link',
#                                                                        'https://gallica.bnf.fr/ark:/12148/bpt6k5839083t'),
#                                                                       ('nqamoyen',
#                                                                        '96.58'),
#                                                                       ('thumbnail',
#                                                                        'https://gallica.bnf.fr/ark:/12148/bpt6k5839083t.thumbnail'),
#                                                                       ('typedoc',
#                                                                        'monographies'),
#                                                                       ('uri',
#                                                                        'bpt6k5839083t')]))]),
#                                            OrderedDict([('srw:recordSchema',
#                                                          'http://www.openarchives.org/OAI/2.0/OAIdc.xsd'),
#                                                         ('srw:recordPacking',
#                                                          'xml'),
#                                                         ('srw:recordData',
#                                                          OrderedDict([('oai_dc:dc',
#                                                                        OrderedDict([('dc:contributor',
#                                                                                      'Martin, Jean (15..-1553?). Traducteur'),
#                                                                                     ('dc:creator',
#                                                                                      ['Vitruve (0090?-0020? av. J.-C.). Auteur du texte',
#                                                                                       'Philandrier, Guillaume (1505-1565). Auteur du texte']),
#                                                                                     ('dc:date',
#                                                                                      '1618'),
#                                                                                     ('dc:description',
#                                                                                      ["[De l'architecture (français). 1618]",
#                                                                                       'Comprend : Vie de Vitruve',
#                                                                                       'Ouvrages avant 1800']),
#                                                                                     ('dc:format',
#                                                                                      ['[13]-391 p. : titre à encadr. et fig. gr. sur bois, carte, portrait gr. ; in-4',
#                                                                                       'Nombre total de vues : 408']),
#                                                                                     ('dc:identifier',
#                                                                                      'https://gallica.bnf.fr/ark:/12148/bpt6k85630d'),
#                                                                                     ('dc:language',
#                                                                                      ['fre',
#                                                                                       'français']),
#                                                                                     ('dc:publisher',
#                                                                                      '(Cologny)'),
#                                                                                     ('dc:relation',
#                                                                                      ['Notice d’oeuvre : http://catalogue.bnf.fr/ark:/12148/cb120094372',
#                                                                                       'Notice du catalogue : http://catalogue.bnf.fr/ark:/12148/cb315949131']),
#                                                                                     ('dc:rights',
#                                                                                      ['domaine public',
#                                                                                       'public domain']),
#                                                                                     ('dc:source',
#                                                                                      'Bibliothèque nationale de France, département Littérature et art, 11941'),
#                                                                                     ('dc:subject',
#                                                                                      'Architecture romaine'),
#                                                                                     ('dc:title',
#                                                                                      'Architecture, ou Art de bien bâtir de Marc Vitruve Pollion mis de latin en françois par Jean Martin,... au roy très-chrestien Henry II'),
#                                                                                     ('dc:type',
#                                                                                      ['text',
#                                                                                       'monographie imprimée',
#                                                                                       'monographie imprimée'])]))])),
#                                                         ('srw:recordIdentifier',
#                                                          'ark'),
#                                                         ('srw:recordPosition',
#                                                          '2'),
#                                                         ('srw:extraRecordData',
#                                                          OrderedDict([('epubFile',
#                                                                        None),
#                                                                       ('infoSupModifiable',
#                                                                        None),
#                                                                       ('link',
#                                                                        'https://gallica.bnf.fr/ark:/12148/bpt6k85630d'),
#                                                                       ('nqamoyen',
#                                                                        '0.0'),
#                                                                       ('thumbnail',
#                                                                        'https://gallica.bnf.fr/ark:/12148/bpt6k85630d.thumbnail'),
#                                                                       ('typedoc',
#                                                                        'monographies'),
#                                                                       ('uri',
#                                                                        'bpt6k85630d')]))]),
#                                            OrderedDict([('srw:recordSchema',
#                                                          'http://www.openarchives.org/OAI/2.0/OAIdc.xsd'),
#                                                         ('srw:recordPacking',
#                                                          'xml'),
#                                                         ('srw:recordData',
#                                                          OrderedDict([('oai_dc:dc',
#                                                                        OrderedDict([('dc:creator',
#                                                                                      ['Serlio, Sebastiano (1475-1554?). Auteur du texte',
#                                                                                       'Coecke van Aelst, Pieter (1502-1550). Graveur',
#                                                                                       'Vitruve (0090?-0020? av. J.-C.). Auteur ou responsable intellectuel',
#                                                                                       'Marie (1505-1558 ; reine de Hongrie). Dédicataire']),
#                                                                                     ('dc:date',
#                                                                                      '1545'),
#                                                                                     ('dc:format',
#                                                                                      ['1 vol. (72 f.) : texte, gravure sur bois ; in-fol.',
#                                                                                       'image/jpeg',
#                                                                                       'Nombre total de vues : 152']),
#                                                                                     ('dc:identifier',
#                                                                                      'https://gallica.bnf.fr/ark:/12148/btv1b8457382h'),
#                                                                                     ('dc:language',
#                                                                                      ['fre',
#                                                                                       'français']),
#                                                                                     ('dc:publisher',
#                                                                                      '(Anvers)'),
#                                                                                     ('dc:relation',
#                                                                                      'Notice du catalogue : http://catalogue.bnf.fr/ark:/12148/cb313544662'),
#                                                                                     ('dc:rights',
#                                                                                      ['domaine public',
#                                                                                       'public domain']),
#                                                                                     ('dc:source',
#                                                                                      'Bibliothèque nationale de France, département Estampes et photographie, PET FOL-HB-9 (A)'),
#                                                                                     ('dc:subject',
#                                                                                      "Vues d'architecture -- 16e siècle"),
#                                                                                     ('dc:title',
#                                                                                      "Reigles generales de l'Architecture, sur les cincq manières d'edifices, a scauoir, Thuscane, Doricq, Ionicq, Corinthe & Composite, avec les exemples danticquitez, selon la doctrine de Vitruue"),
#                                                                                     ('dc:type',
#                                                                                      ['image fixe',
#                                                                                       'image',
#                                                                                       'still image',
#                                                                                       'estampe',
#                                                                                       'engraving'])]))])),
#                                                         ('srw:recordIdentifier',
#                                                          'ark'),
#                                                         ('srw:recordPosition',
#                                                          '3'),
#                                                         ('srw:extraRecordData',
#                                                          OrderedDict([('epubFile',
#                                                                        None),
#                                                                       ('infoSupModifiable',
#                                                                        None),
#                                                                       ('link',
#                                                                        'https://gallica.bnf.fr/ark:/12148/btv1b8457382h'),
#                                                                       ('nqamoyen',
#                                                                        '0.0'),
#                                                                       ('thumbnail',
#                                                                        'https://gallica.bnf.fr/ark:/12148/btv1b8457382h.thumbnail'),
#                                                                       ('typedoc',
#                                                                        'images'),
#                                                                       ('uri',
#                                                                        'btv1b8457382h')]))]),
#                                            OrderedDict([('srw:recordSchema',
#                                                          'http://www.openarchives.org/OAI/2.0/OAIdc.xsd'),
#                                                         ('srw:recordPacking',
#                                                          'xml'),
#                                                         ('srw:recordData',
#                                                          OrderedDict([('oai_dc:dc',
#                                                                        OrderedDict([('dc:contributor',
#                                                                                      'Perrault, Claude (1613-1688). Traducteur'),
#                                                                                     ('dc:creator',
#                                                                                      'Vitruve (0090?-0020? av. J.-C.). Auteur du texte'),
#                                                                                     ('dc:date',
#                                                                                      '1673'),
#                                                                                     ('dc:description',
#                                                                                      ["[De l'architecture (français). 1673]",
#                                                                                       'Ouvrages avant 1800']),
#                                                                                     ('dc:format',
#                                                                                      ['[16]-325 p. : frontisp. et fig. gr. sur cuivre, musique gr. sur bois ; in-fol.',
#                                                                                       'Nombre total de vues : 367']),
#                                                                                     ('dc:identifier',
#                                                                                      'https://gallica.bnf.fr/ark:/12148/bpt6k85660b'),
#                                                                                     ('dc:language',
#                                                                                      ['fre',
#                                                                                       'français']),
#                                                                                     ('dc:publisher',
#                                                                                      '(Paris)'),
#                                                                                     ('dc:relation',
#                                                                                      ['Notice d’oeuvre : http://catalogue.bnf.fr/ark:/12148/cb120094372',
#                                                                                       'Notice du catalogue : http://catalogue.bnf.fr/ark:/12148/cb315949162']),
#                                                                                     ('dc:rights',
#                                                                                      ['domaine public',
#                                                                                       'public domain']),
#                                                                                     ('dc:source',
#                                                                                      'Bibliothèque nationale de France, département Littérature et art, V-1935'),
#                                                                                     ('dc:subject',
#                                                                                      'Architecture'),
#                                                                                     ('dc:title',
#                                                                                      "Les dix livres d'architecture de Vitruve , corrigez et traduits nouvellement en françois avec des notes et des figures"),
#                                                                                     ('dc:type',
#                                                                                      ['text',
#                                                                                       'monographie imprimée',
#                                                                                       'monographie imprimée'])]))])),
#                                                         ('srw:recordIdentifier',
#                                                          'ark'),
#                                                         ('srw:recordPosition',
#                                                          '4'),
#                                                         ('srw:extraRecordData',
#                                                          OrderedDict([('epubFile',
#                                                                        None),
#                                                                       ('infoSupModifiable',
#                                                                        None),
#                                                                       ('link',
#                                                                        'https://gallica.bnf.fr/ark:/12148/bpt6k85660b'),
#                                                                       ('nqamoyen',
#                                                                        '0.0'),
#                                                                       ('thumbnail',
#                                                                        'https://gallica.bnf.fr/ark:/12148/bpt6k85660b.thumbnail'),
#                                                                       ('typedoc',
#                                                                        'monographies'),
#                                                                       ('uri',
#                                                                        'bpt6k85660b')]))]),
#                                            OrderedDict([('srw:recordSchema',
#                                                          'http://www.openarchives.org/OAI/2.0/OAIdc.xsd'),
#                                                         ('srw:recordPacking',
#                                                          'xml'),
#                                                         ('srw:recordData',
#                                                          OrderedDict([('oai_dc:dc',
#                                                                        OrderedDict([('dc:creator',
#                                                                                      ['Choisy, Auguste (1841-1909). Auteur du texte',
#                                                                                       'Vitruve (0090?-0020? av. J.-C.). Auteur du texte']),
#                                                                                     ('dc:date',
#                                                                                      '1909'),
#                                                                                     ('dc:description',
#                                                                                      'Appartient à l’ensemble documentaire : BibINHA'),
#                                                                                     ('dc:format',
#                                                                                      '4 tomes en 2 vol. in-4 ou 4 vol. gr. in-8, dont un de pl.'),
#                                                                                     ('dc:identifier',
#                                                                                      'https://gallica.bnf.fr/ark:/12148/bpt6k61029198'),
#                                                                                     ('dc:language',
#                                                                                      'fre'),
#                                                                                     ('dc:publisher',
#                                                                                      '(Paris)'),
#                                                                                     ('dc:relation',
#                                                                                      ["Notice d'ensemble : http://catalogue.bnf.fr/ark:/12148/cb315949073",
#                                                                                       'Notice du catalogue : http://catalogue.bnf.fr/ark:/12148/cb315949073']),
#                                                                                     ('dc:rights',
#                                                                                      ['domaine public',
#                                                                                       'public domain']),
#                                                                                     ('dc:source',
#                                                                                      "Bibliothèque de l'INHA / coll. J. Doucet, 2010-94052"),
#                                                                                     ('dc:title',
#                                                                                      'Vitruve. Tome 4 / Auguste Choisy'),
#                                                                                     ('dc:type',
#                                                                                      ['text',
#                                                                                       'monographie imprimée',
#                                                                                       'monographie imprimée'])]))])),
#                                                         ('srw:recordIdentifier',
#                                                          'ark'),
#                                                         ('srw:recordPosition',
#                                                          '5'),
#                                                         ('srw:extraRecordData',
#                                                          OrderedDict([('epubFile',
#                                                                        None),
#                                                                       ('infoSupModifiable',
#                                                                        None),
#                                                                       ('link',
#                                                                        'https://gallica.bnf.fr/ark:/12148/bpt6k61029198'),
#                                                                       ('nqamoyen',
#                                                                        '96.77'),
#                                                                       ('thumbnail',
#                                                                        'https://gallica.bnf.fr/ark:/12148/bpt6k61029198.thumbnail'),
#                                                                       ('typedoc',
#                                                                        'monographies'),
#                                                                       ('uri',
#                                                                        'bpt6k61029198')]))]),
#                                            OrderedDict([('srw:recordSchema',
#                                                          'http://www.openarchives.org/OAI/2.0/OAIdc.xsd'),
#                                                         ('srw:recordPacking',
#                                                          'xml'),
#                                                         ('srw:recordData',
#                                                          OrderedDict([('oai_dc:dc',
#                                                                        OrderedDict([('dc:creator',
#                                                                                      ['Vitruve (0090?-0020? av. J.-C.). Auteur du texte',
#                                                                                       'Perrault, Claude (1613-1688). Auteur du texte']),
#                                                                                     ('dc:date',
#                                                                                      '1674'),
#                                                                                     ('dc:description',
#                                                                                      ["[De l'architecture. Extraitfrançais). 1674]",
#                                                                                       'Appartient à l’ensemble documentaire : GTextes1',
#                                                                                       'Contient une table des matières',
#                                                                                       'Avec mode texte']),
#                                                                                     ('dc:format',
#                                                                                      ['[10]-224-[39] p.-XI f. de pl. ; in-12',
#                                                                                       'Nombre total de vues : 289']),
#                                                                                     ('dc:identifier',
#                                                                                      'https://gallica.bnf.fr/ark:/12148/bpt6k5834144h'),
#                                                                                     ('dc:language',
#                                                                                      ['fre',
#                                                                                       'français']),
#                                                                                     ('dc:publisher',
#                                                                                      '(Paris)'),
#                                                                                     ('dc:relation',
#                                                                                      ["Notice d'ensemble : http://catalogue.bnf.fr/ark:/12148/cb443352645",
#                                                                                       'Notice d’oeuvre : http://catalogue.bnf.fr/ark:/12148/cb120094372',
#                                                                                       'Notice du catalogue : http://catalogue.bnf.fr/ark:/12148/cb31084855m']),
#                                                                                     ('dc:rights',
#                                                                                      ['domaine public',
#                                                                                       'public domain']),
#                                                                                     ('dc:source',
#                                                                                      'Bibliothèque nationale de France, département Littérature et art, V-21991'),
#                                                                                     ('dc:title',
#                                                                                      "Abrégé des dix livres d'architecture de Vitruve"),
#                                                                                     ('dc:type',
#                                                                                      ['text',
#                                                                                       'monographie imprimée',
#                                                                                       'monographie imprimée'])]))])),
#                                                         ('srw:recordIdentifier',
#                                                          'ark'),
#                                                         ('srw:recordPosition',
#                                                          '6'),
#                                                         ('srw:extraRecordData',
#                                                          OrderedDict([('epubFile',
#                                                                        None),
#                                                                       ('infoSupModifiable',
#                                                                        None),
#                                                                       ('link',
#                                                                        'https://gallica.bnf.fr/ark:/12148/bpt6k5834144h'),
#                                                                       ('nqamoyen',
#                                                                        '81.75'),
#                                                                       ('thumbnail',
#                                                                        'https://gallica.bnf.fr/ark:/12148/bpt6k5834144h.thumbnail'),
#                                                                       ('typedoc',
#                                                                        'monographies'),
#                                                                       ('uri',
#                                                                        'bpt6k5834144h')]))]),
#                                            OrderedDict([('srw:recordSchema',
#                                                          'http://www.openarchives.org/OAI/2.0/OAIdc.xsd'),
#                                                         ('srw:recordPacking',
#                                                          'xml'),
#                                                         ('srw:recordData',
#                                                          OrderedDict([('oai_dc:dc',
#                                                                        OrderedDict([('dc:contributor',
#                                                                                      'Giocondo, Giovanni (1433?-1515). Éditeur scientifique'),
#                                                                                     ('dc:creator',
#                                                                                      'Vitruve (0090?-0020? av. J.-C.). Auteur du texte'),
#                                                                                     ('dc:date',
#                                                                                      '1511'),
#                                                                                     ('dc:description',
#                                                                                      'Numérisation partielle de reliure'),
#                                                                                     ('dc:format',
#                                                                                      ["In-fol., dédicace, table, 110 ff. et l'index, car. rom., titre à encadr. et fig. gr. sur bois, marque typogr. à la fin",
#                                                                                       'Nombre total de vues : 4']),
#                                                                                     ('dc:identifier',
#                                                                                      'https://gallica.bnf.fr/ark:/12148/btv1b73002165'),
#                                                                                     ('dc:language',
#                                                                                      ['lat',
#                                                                                       'latin']),
#                                                                                     ('dc:relation',
#                                                                                      'Notice du catalogue : http://catalogue.bnf.fr/ark:/12148/cb31594885m'),
#                                                                                     ('dc:rights',
#                                                                                      ['domaine public',
#                                                                                       'public domain']),
#                                                                                     ('dc:source',
#                                                                                      'Bibliothèque nationale de France, département Réserve des livres rares, RES-V-319'),
#                                                                                     ('dc:title',
#                                                                                      'Reliure de : M. Vitruvius per Jocundum solito castigatior factus cum figuris et tabula ut jam legi et intelligi possit. - "À la fin" : Impressum Venetiis... sumtu miraque diligentia Joannis de Tridino alias Tacuino, anno Domini MDXI, die XXII. maii...'),
#                                                                                     ('dc:type',
#                                                                                      ['text',
#                                                                                       'monographie imprimée',
#                                                                                       'monographie imprimée'])]))])),
#                                                         ('srw:recordIdentifier',
#                                                          'ark'),
#                                                         ('srw:recordPosition',
#                                                          '7'),
#                                                         ('srw:extraRecordData',
#                                                          OrderedDict([('epubFile',
# ...
#                                                                                     ('dc:identifier',
#                                                                                      'https://gallica.bnf.fr/ark:/12148/btv1b8539705d'),
#                                                                                     ('dc:language',
#                                                                                      'fre'),
#                                                                                     ('dc:relation',
#                                                                                      'Notice du catalogue : http://archivesetmanuscrits.bnf.fr/ark:/12148/cc43527x'),
#                                                                                     ('dc:rights',
#                                                                                      ['domaine public',
#                                                                                       'public domain']),
#                                                                                     ('dc:source',
#                                                                                      'Bibliothèque nationale de France. Département des Manuscrits. Français 12338'),
#                                                                                     ('dc:title',
#                                                                                      "Vitruve, Premier livre d'architecture , traduction en français par Jean Martin"),
#                                                                                     ('dc:type',
#                                                                                      ['manuscript',
#                                                                                       'manuscrit'])]))])),
#                                                         ('srw:recordIdentifier',
#                                                          'ark'),
#                                                         ('srw:recordPosition',
#                                                          '12'),
#                                                         ('srw:extraRecordData',
#                                                          OrderedDict([('epubFile',
#                                                                        None),
#                                                                       ('infoSupModifiable',
#                                                                        None),
#                                                                       ('link',
#                                                                        'https://gallica.bnf.fr/ark:/12148/btv1b8539705d'),
#                                                                       ('nqamoyen',
#                                                                        '0.0'),
#                                                                       ('thumbnail',
#                                                                        'https://gallica.bnf.fr/ark:/12148/btv1b8539705d.thumbnail'),
#                                                                       ('typedoc',
#                                                                        'manuscrits'),
#                                                                       ('uri',
#                                                                        'btv1b8539705d')]))]),
#                                            OrderedDict([('srw:recordSchema',
#                                                          'http://www.openarchives.org/OAI/2.0/OAIdc.xsd'),
#                                                         ('srw:recordPacking',
#                                                          'xml'),
#                                                         ('srw:recordData',
#                                                          OrderedDict([('oai_dc:dc',
#                                                                        OrderedDict([('dc:contributor',
#                                                                                      ['Nisard, Désiré (1806-1888). Éditeur scientifique',
#                                                                                       'Ninnin, Henri. Traducteur',
#                                                                                       'Perrault, Claude (1613-1688). Préfacier']),
#                                                                                     ('dc:creator',
#                                                                                      ['Celse (0029 av. J.-C. -0037). Auteur du texte',
#                                                                                       'Vitruve (0090?-0020? av. J.-C.). Auteur du texte',
#                                                                                       'Censorinus. Auteur du texte',
#                                                                                       'Frontin (0030?-0103?). Auteur du texte']),
#                                                                                     ('dc:date',
#                                                                                      '1866'),
#                                                                                     ('dc:description',
#                                                                                      ['Collection : Collection des auteurs latins avec la traduction en français',
#                                                                                       'Collection : Collection des auteurs latins avec la traduction en français',
#                                                                                       "Comprend : Traité de la médecine ; De l'architecture / M. Vitruve Pollion ; Préface de C. Perrault,... ; Du jour natal ; Des aqueducs de Rome"]),
#                                                                                     ('dc:format',
#                                                                                      ['1 vol. (VIII- 289, 410 p.) ; in-8',
#                                                                                       'Nombre total de vues : 714']),
#                                                                                     ('dc:identifier',
#                                                                                      'https://gallica.bnf.fr/ark:/12148/bpt6k282064f'),
#                                                                                     ('dc:language',
#                                                                                      'fre'),
#                                                                                     ('dc:publisher',
#                                                                                      '(Paris)'),
#                                                                                     ('dc:relation',
#                                                                                      'Notice du catalogue : http://catalogue.bnf.fr/ark:/12148/cb401757994'),
#                                                                                     ('dc:rights',
#                                                                                      ['domaine public',
#                                                                                       'public domain']),
#                                                                                     ('dc:source',
#                                                                                      'Bibliothèque nationale de France'),
#                                                                                     ('dc:title',
#                                                                                      'Celse, Vitruve, Censorin : oeuvres complètes. Frontin (des aqueducs de Rome) : avec la traduction en français / publiés sous la direction de M. Nisard,...'),
#                                                                                     ('dc:type',
#                                                                                      ['text',
#                                                                                       'monographie imprimée',
#                                                                                       'monographie imprimée'])]))])),
#                                                         ('srw:recordIdentifier',
#                                                          'ark'),
#                                                         ('srw:recordPosition',
#                                                          '13'),
#                                                         ('srw:extraRecordData',
#                                                          OrderedDict([('epubFile',
#                                                                        None),
#                                                                       ('infoSupModifiable',
#                                                                        None),
#                                                                       ('link',
#                                                                        'https://gallica.bnf.fr/ark:/12148/bpt6k282064f'),
#                                                                       ('nqamoyen',
#                                                                        '89.58'),
#                                                                       ('thumbnail',
#                                                                        'https://gallica.bnf.fr/ark:/12148/bpt6k282064f.thumbnail'),
#                                                                       ('typedoc',
#                                                                        'monographies'),
#                                                                       ('uri',
#                                                                        'bpt6k282064f')]))]),
#                                            OrderedDict([('srw:recordSchema',
#                                                          'http://www.openarchives.org/OAI/2.0/OAIdc.xsd'),
#                                                         ('srw:recordPacking',
#                                                          'xml'),
#                                                         ('srw:recordData',
#                                                          OrderedDict([('oai_dc:dc',
#                                                                        OrderedDict([('dc:creator',
#                                                                                      ['Cléonide. Auteur du texte',
#                                                                                       'Vitruve (0090?-0020? av. J.-C.). Auteur du texte',
#                                                                                       'Frontin (0030?-0103?). Auteur du texte']),
#                                                                                     ('dc:date',
#                                                                                      '1497'),
#                                                                                     ('dc:description',
#                                                                                      'Comprend : L. Vitruvii Pollionis De architectura libri decem ; Sexti Julii Frontini De aquaeductibus liber unus'),
#                                                                                     ('dc:format',
#                                                                                      ['[192] p. ; in-fol.',
#                                                                                       'Nombre total de vues : 190']),
#                                                                                     ('dc:identifier',
#                                                                                      'https://gallica.bnf.fr/ark:/12148/bpt6k201038q'),
#                                                                                     ('dc:language',
#                                                                                      ['lat',
#                                                                                       'latin']),
#                                                                                     ('dc:publisher',
#                                                                                      '(Venetiis)'),
#                                                                                     ('dc:relation',
#                                                                                      'Notice du catalogue : http://catalogue.bnf.fr/ark:/12148/cb31130989c'),
#                                                                                     ('dc:rights',
#                                                                                      ['domaine public',
#                                                                                       'public domain']),
#                                                                                     ('dc:source',
#                                                                                      'Bibliothèque nationale de France, département Réserve des livres rares, Rés. V-318'),
#                                                                                     ('dc:title',
#                                                                                      'Cleonidae Harmonicum introductorium / interprete Georgio Valla. L. Vitruvii Pollionis De architectura libri decem. Sexti Julii Frontini De aquaeductibus liber unus'),
#                                                                                     ('dc:type',
#                                                                                      ['text',
#                                                                                       'monographie imprimée',
#                                                                                       'monographie imprimée'])]))])),
#                                                         ('srw:recordIdentifier',
#                                                          'ark'),
#                                                         ('srw:recordPosition',
#                                                          '14'),
#                                                         ('srw:extraRecordData',
#                                                          OrderedDict([('epubFile',
#                                                                        None),
#                                                                       ('infoSupModifiable',
#                                                                        None),
#                                                                       ('link',
#                                                                        'https://gallica.bnf.fr/ark:/12148/bpt6k201038q'),
#                                                                       ('nqamoyen',
#                                                                        '0.0'),
#                                                                       ('thumbnail',
#                                                                        'https://gallica.bnf.fr/ark:/12148/bpt6k201038q.thumbnail'),
#                                                                       ('typedoc',
#                                                                        'monographies'),
#                                                                       ('uri',
#                                                                        'bpt6k201038q')]))])])])),
#                            ('srw:nextRecordPosition', '16')]))])

# %% [markdown]
# Write a function that from a query will fetch all records corresponding to that query and parse them to dictionnaries.
#
# First try to parse the records from a single request.
#
# Then, you will realize that if your query has many results you need to make requests of "blocks" (first 50 records, then next 50, etc...) as the server will not give you all of them directly (to avoid too big response). The additional `maximumRecords` and `startRecord` HTTP parameters can be specified in the query to specify how many, and the starting record desired. For instance with `maximumRecords=50&startRecord=50` the response will be about the results number 50 to 100.

# %%
def search_gallica(query, max_records=None):
    # Your code here
    NUM_RESULTS_PER_QUERY = 50
    nb_total_records = get_nb_total_records(query)
    if max_records:
        nb_total_records = min(max_records, nb_total_records)
        
    all_records = []
    for offset in range(0, nb_total_records, NUM_RESULTS_PER_QUERY):
        # Fetch a page of results
        full_xml_response = request_and_parse(SRU_BASEURL + quote_plus(query) + f"&maximumRecords={NUM_RESULTS_PER_QUERY}&startRecord={offset}")
        records = full_xml_response['srw:searchRetrieveResponse']['srw:records']['srw:record']
        # Parse results
        for r in records:
            tmp_record = dict(r['srw:recordData']['oai_dc:dc'])
            tmp_record['srw:extraRecordData'] = dict(r['srw:extraRecordData'])
            all_records.append(tmp_record)
    
    return all_records
    
def get_nb_total_records(query):
    """Fetch in the search result the total number of records"""
    result_parsed = request_and_parse(SRU_BASEURL + quote_plus(query) + "&maximumRecords=0")
    try:
        return int(result_parsed['srw:searchRetrieveResponse']['srw:numberOfRecords'])
    except KeyError:
        return 0

# %%
query = '(dc.creator all "Vitruve")'
records = search_gallica(query)
assert isinstance(records, list)
assert len(records) == 62
# Out:
# Fetching https://gallica.bnf.fr/SRU?version=1.2&operation=searchRetrieve&suggest=0&query=%28dc.creator+all+%22Vitruve%22%29&maximumRecords=0
# Fetching https://gallica.bnf.fr/SRU?version=1.2&operation=searchRetrieve&suggest=0&query=%28dc.creator+all+%22Vitruve%22%29&maximumRecords=50&startRecord=0
# Fetching https://gallica.bnf.fr/SRU?version=1.2&operation=searchRetrieve&suggest=0&query=%28dc.creator+all+%22Vitruve%22%29&maximumRecords=50&startRecord=50

# %% [markdown]
# ## Get Pagination info from API
#
# Write a small function that checks if the full text is present from the pagination info

# %%
def get_pagination_info(key):
    return request_and_parse(f"https://gallica.bnf.fr/services/Pagination?ark={key}")

def has_full_text(pagination_info):
    # Your code here
    return pagination_info['livre']['structure']['hasContent'] == 'true'

pag_info_1 = get_pagination_info('btv1b21000411')
print("Should be False : ", has_full_text(pag_info_1))
pag_info_2 = get_pagination_info('bpt6k5839083t')
print("Should be True : ", has_full_text(pag_info_2))
# Out:
# Fetching https://gallica.bnf.fr/services/Pagination?ark=btv1b21000411
# Should be False :  False
# Fetching https://gallica.bnf.fr/services/Pagination?ark=bpt6k5839083t
# Should be True :  True

# %% [markdown]
# ## Download the OCRized text
#
# Given the url of a gallica resource (for instance https://gallica.bnf.fr/ark:/12148/bpt6k236629), one can access the OCRized text (if it exists) by appending `.texteBrut` (https://gallica.bnf.fr/ark:/12148/bpt6k236629.texteBrut).
#
# It is also possible to always download directly the images or the PDF, since this resource has 588 pages, one can directly download the PDF of pages 1 to 588 with:
#
# https://gallica.bnf.fr/ark:/12148/bpt6k236629/f1n588.pdf
#
# Or for a smaller file, just pages 1 to 10:
#
# https://gallica.bnf.fr/ark:/12148/bpt6k236629/f1n10.pdf
#
# Here, we will try to download the OCRized text and save it to a text file. By default, the resource of the text (for instance https://gallica.bnf.fr/ark:/12148/bpt6k236629.texteBrut, open the developer view and inspector to look at the html structure) is in HTML and with an annoying header at the top, so we will be able to play a bit with HTML parsing to convert it to proper text.

# %%
from bs4 import BeautifulSoup

def get_html_text(identifier):
    url = identifier+'.texteBrut'
    print(f"Fetching {url}")
    data = requests.get(url)
    return data.content

def get_full_text(raw_html):
    soup = BeautifulSoup(raw_html)
    html_body = soup.find('body')
    
    # Iterates over the children of the html body
    # Discard the blocks before the first <hr> (horizontal row)  (use .name to know what kind of tag it is)
    # Concatenate the text of the elements after (use .get_text() )
    passed_header = False
    texts = []
    for child in html_body.children:
        if child.name == 'hr':
            passed_header = True
        if passed_header:
            texts.append(child.get_text())
    return '\n'.join(texts)

# %%
html_text = get_html_text('https://gallica.bnf.fr/ark:/12148/bpt6k236629')
# Out:
# Fetching https://gallica.bnf.fr/ark:/12148/bpt6k236629.texteBrut

# %%
parsed_text = get_full_text(html_text)
assert isinstance(parsed_text, str)
# Yes the OCR output is really far from being great, probably old OCR software, we can do much better now
print(parsed_text[:1000])
# Out:
# ~(9~ a~~g
# Ï'Et.A
# BIBLIOTtIÈQUE
# Mm-FRA~!SE traductions nouvelles
# DES AUTEURS LATINE
# AVEC LE TEXTE EN REGARD
# DEPUIS ADRIEN ~C8Qt)'A CBEeOtBE DE TOBBS
# pubfiëe
# PAR C. L.F PANCKOUCKE N
# orxrcrxx ne ce Lecrnn n'nwxene
# VITRUVE j!
# traduction )joav<!)!f
# ( Mvee de Membretn~eo a~mrea pour t tm<eMig<-n<M- du «~ PAR M.CH.L.MAUFRAS
# Membre de la Société (tea antiquaires de Normandie
# de )a Société t'anÉenne du Calvados
# de la &ooete pbur la conservation et la description des moniirnent~ hist~xni.~
# professeuraucoUegeRnNin
# TOME PREMŒR
# PARIS
# C. L. F. PANCEOUCKE. EDITEUR B[;E DES POITEVINS, 14
# 18~7
#
#
# SECONDE SÉRIE
# DEt.t
# B~LIOTHÈQUE
# Hït~-FM~~ttS)' D"UfS ADK.EM JUSQU'A SRf:GO..iE DE TOU.!S
# p.M..
# PARC. L. F. PANCKO~CKH
#
# mpKntmuEPANCKfn'r.tix,
# ruedMroitc"
#
# LARCHtTECTURE
# 0);
# VITRtJVE
# "rI\.AUIiGl'JO."o! t'oOfJ\' }o:l.l~
# PAttt.m.-t. Mms
# de la Soci~tl; des antiquaires (le NOI"mandie. dl' la Soci~té liulleenne du C.1~ad..
# --t~ et la desCl'iption des mOIHunell1s 11istoriq1Jes,
# P'e

# %%
import os
OUTPUT_FOLDER = 'gallica_output'
os.makedirs(OUTPUT_FOLDER, exist_ok=True)

# For every record, try to get the full text and save it to a file
# Note that many documents are actually not OCRized
for record in records:
    try:
        key = record['srw:extraRecordData']['uri']
        pagination_info = get_pagination_info(key)
        if has_full_text(pagination_info):
            print(f'{key} has full text')
            html_text = get_html_text(record['dc:identifier'])
            full_text = get_full_text(html_text)
            with open(os.path.join(OUTPUT_FOLDER, f'{key}.txt'), 'w', encoding='utf-8') as f:
                print(f'Saving {key}.txt')
                f.write(full_text)
    except Exception as e:
        print(f'Failed for {record["dc:identifier"]}, {e}')
# Out:
# Fetching https://gallica.bnf.fr/services/Pagination?ark=btv1b21000411
# Fetching https://gallica.bnf.fr/services/Pagination?ark=bpt6k5839083t
# bpt6k5839083t has full text
# Fetching https://gallica.bnf.fr/ark:/12148/bpt6k5839083t.texteBrut
# Saving bpt6k5839083t.txt
# Fetching https://gallica.bnf.fr/services/Pagination?ark=bpt6k85630d
# Fetching https://gallica.bnf.fr/services/Pagination?ark=btv1b8457382h
# Fetching https://gallica.bnf.fr/services/Pagination?ark=bpt6k85660b
# Fetching https://gallica.bnf.fr/services/Pagination?ark=bpt6k61029198
# bpt6k61029198 has full text
# Fetching https://gallica.bnf.fr/ark:/12148/bpt6k61029198.texteBrut
# Saving bpt6k61029198.txt
# Fetching https://gallica.bnf.fr/services/Pagination?ark=bpt6k5834144h
# bpt6k5834144h has full text
# Fetching https://gallica.bnf.fr/ark:/12148/bpt6k5834144h.texteBrut
# Saving bpt6k5834144h.txt
# Fetching https://gallica.bnf.fr/services/Pagination?ark=btv1b73002165
# Fetching https://gallica.bnf.fr/services/Pagination?ark=bpt6k236629
# bpt6k236629 has full text
# Fetching https://gallica.bnf.fr/ark:/12148/bpt6k236629.texteBrut
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/miniconda3/envs/archi/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     376             try:  # Python 2.7, use buffering of HTTP responses
# --> 377                 httplib_response = conn.getresponse(buffering=True)
#     378             except TypeError:  # Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-32-11ce70f37d87> in <module>
#      11         if has_full_text(pagination_info):
#      12             print(f'{key} has full text')
# ---> 13             html_text = get_html_text(record['dc:identifier'])
#      14             full_text = get_full_text(html_text)
#      15             with open(os.path.join(OUTPUT_FOLDER, f'{key}.txt'), 'w', encoding='utf-8') as f:
#
# <ipython-input-29-3fb5d4342793> in get_html_text(identifier)
#       4     url = identifier+'.texteBrut'
#       5     print(f"Fetching {url}")
# ----> 6     data = requests.get(url)
#       7     return data.content
#       8
#
# ~/miniconda3/envs/archi/lib/python3.6/site-packages/requests/api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# ~/miniconda3/envs/archi/lib/python3.6/site-packages/requests/api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# ~/miniconda3/envs/archi/lib/python3.6/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# ~/miniconda3/envs/archi/lib/python3.6/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# ~/miniconda3/envs/archi/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# ~/miniconda3/envs/archi/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# ~/miniconda3/envs/archi/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     378             except TypeError:  # Python 3
#     379                 try:
# --> 380                     httplib_response = conn.getresponse()
#     381                 except Exception as e:
#     382                     # Remove the TypeError from the exception chain in Python 3;
#
# ~/miniconda3/envs/archi/lib/python3.6/http/client.py in getresponse(self)
#    1329         try:
#    1330             try:
# -> 1331                 response.begin()
#    1332             except ConnectionError:
#    1333                 self.close()
#
# ~/miniconda3/envs/archi/lib/python3.6/http/client.py in begin(self)
#     295         # read until we get a non-100 response
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#     299                 break
#
# ~/miniconda3/envs/archi/lib/python3.6/http/client.py in _read_status(self)
#     256
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#     260             raise LineTooLong("status line")
#
# ~/miniconda3/envs/archi/lib/python3.6/socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# ~/miniconda3/envs/archi/lib/python3.6/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     295     def recv_into(self, *args, **kwargs):
#     296         try:
# --> 297             return self.connection.recv_into(*args, **kwargs)
#     298         except OpenSSL.SSL.SysCallError as e:
#     299             if self.suppress_ragged_eofs and e.args == (-1, 'Unexpected EOF'):
#
# ~/miniconda3/envs/archi/lib/python3.6/site-packages/OpenSSL/SSL.py in recv_into(self, buffer, nbytes, flags)
#    1819             result = _lib.SSL_peek(self._ssl, buf, nbytes)
#    1820         else:
# -> 1821             result = _lib.SSL_read(self._ssl, buf, nbytes)
#    1822         self._raise_ssl_error(self._ssl, result)
#    1823
#
# KeyboardInterrupt:
